# %% [markdown]
# <a href="https://colab.research.google.com/github/leonlpz/Reconocimiento_de_Patrones/blob/main/Batch_MiniBatch_Stochastic_GradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Red neuronal básica.
#
#
# Una de las técnicas más usadas para estimar los parámetros de una red neuronal es el gradiente descendente, el cual es un algoritmo iterativo donde el valor de los parámetros en la iteración actual depende del valor en la iteración pasada y del valor de los gradientes.
#
#
# $$w^{(t)} = w^{(t-1)} - \eta\frac{\partial J(w)}{\partial w},$$
#
#
# donde $\eta$ es el factor de aprendizaje y $J(w)$ es la función de pérdida. El cálculo de las derivadas se hace a partir de los datos de entrenamiento y dependiendo de la proporción de los datos de datos entrenamiento que usemos en dicho cálculo, se reconocen tres enfoques:
#
#
# 1. Gradiente descendente por lotes.
# 2. Gradiente descendente estocástico.
# 3. Gradiente descendente por mini-lotes.
#
#
# En este documento explicaremos, a partir de un ejemplo práctico, las principales ventajas y desventajas de cada enfoque.
#
#
#
# ## Etapa 1: Definición de los datos.
#
#
# Antes de comenzar con el estudio de los tres enfoques de optimización, definimos la base de datos de interés. Para este caso particular, usaremos una base de datos sintética con dos atributos y que configura un problema de clasificación con 3 clases ([Ver enlace](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html))

# %% [markdown]
# Se cargan las librerías necesarias

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.utils import plot_model
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %% [markdown]
# Se crea la base de datos y se divide en los conjuntos de entrenamiento y prueba. Se definen 1000 muestras de las cuales el 80% se usa en el entrenamiento y el 20% restante para el conjunto de prueba.

# %%
n = 1000
classes = 3
dimensions = 2

train_size = int(n * 0.8)

X, y = make_blobs(
    n_samples=n,
    centers=classes,
    n_features=dimensions,
    cluster_std=2,
    random_state=42
)

x_train, x_test = X[:train_size,:], X[train_size:,:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
print(x_train.shape)
# Out:
# (800, 2)

# %% [markdown]
# Ahora escribiremos algunas funciones que nos serán útiles para definir y entrenar el modelo de redes neuronales. Se llevarán a cabo tres experimentos (uno por cada enfoque de optimización) que usarán exactamente la misma red, lo único que se varía es el enfoque de optimización.

# %%
# Esta función permite definir y entrenar una red neuronal. La función tiene dos
# argumentos de entrada. El primero es el tamaño del lote; el segundo, es el tipo
# de optimización que se usará para el entrenamiento.
def fit_model(batch_size):
    # Se define una red con un única capa oculta con 32 unidades y activación ReLU.
    model = Sequential([
        Dense(32, input_dim=dimensions, activation="relu"),
        Dense(classes, activation="softmax")
    ])

    # Se compila el modelo usando un optimizador basado en gradiente descendente
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.90),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    history = model.fit(
        x_train,
        y_train,
        validation_data=(x_test, y_test),
        epochs=100,
        batch_size=batch_size
    )

    return model, history


def evaluate(model, history):
    # Se evalúa el accuracy del modelo tanto en el conjunto de entrenamiento como
    # en el de prueba.
    _, train_accuracy = model.evaluate(x_train, y_train)
    _, test_accuracy = model.evaluate(x_test, y_test)

    print(f"Trainining accuracy: {train_accuracy:.2f}")
    print(f"Testing accuracy: {test_accuracy:.2f}")

    # Se grafica la función de pérdida para los conjuntos de entrenamiento y
    # prueba.
    plt.figure(figsize=(6, 4), dpi=160)

    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="test")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Etapa 2: Gradiente descendente por lotes.
#
# En este primer enfoque corresponde al gradiente descendente por lotes. En este método de optimización se usan todos los datos disponibles en el conjunto de entrenamiento. En nuestro caso particular, el conjunto entrenamiento está compuesto por 800 muestras, así definimos:
# `batch_size = 800`.
#
# En este caso, dado que en cada iteración de la optimización se usan todos los datos del entrenamiento, el parámetro `epochs`, usado en el `model.fit`, indica la cantidad de iteraciones de la fase de entrenamiento.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1

model, history = fit_model(batch_size=800)
evaluate(model, history)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4963 - accuracy: 0.2663 - val_loss: 1.2067 - val_accuracy: 0.3850
# Epoch 2/100
# 1/1 [==============================] - 0s 199ms/step - loss: 1.2257 - accuracy: 0.3800 - val_loss: 0.8147 - val_accuracy: 0.6450
# Epoch 3/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.8202 - accuracy: 0.6525 - val_loss: 0.4700 - val_accuracy: 0.9050
# Epoch 4/100
# 1/1 [==============================] - 0s 158ms/step - loss: 0.4643 - accuracy: 0.9087 - val_loss: 0.2765 - val_accuracy: 0.9500
# Epoch 5/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.2704 - accuracy: 0.9438 - val_loss: 0.1898 - val_accuracy: 0.9550
# Epoch 6/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.1879 - accuracy: 0.9513 - val_loss: 0.1458 - val_accuracy: 0.9600
# Epoch 7/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.1475 - accuracy: 0.9575 - val_loss: 0.1173 - val_accuracy: 0.9750
# Epoch 8/100
# 1/1 [==============================] - 0s 161ms/step - loss: 0.1217 - accuracy: 0.9625 - val_loss: 0.0961 - val_accuracy: 0.9800
# Epoch 9/100
# 1/1 [==============================] - 0s 133ms/step - loss: 0.1026 - accuracy: 0.9688 - val_loss: 0.0796 - val_accuracy: 0.9800
# Epoch 10/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0875 - accuracy: 0.9712 - val_loss: 0.0665 - val_accuracy: 0.9800
# Epoch 11/100
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0754 - accuracy: 0.9787 - val_loss: 0.0563 - val_accuracy: 0.9850
# Epoch 12/100
# 1/1 [==============================] - 0s 208ms/step - loss: 0.0656 - accuracy: 0.9812 - val_loss: 0.0481 - val_accuracy: 0.9850
# Epoch 13/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0577 - accuracy: 0.9837 - val_loss: 0.0416 - val_accuracy: 0.9850
# Epoch 14/100
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0515 - accuracy: 0.9875 - val_loss: 0.0362 - val_accuracy: 0.9900
# Epoch 15/100
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0466 - accuracy: 0.9887 - val_loss: 0.0318 - val_accuracy: 0.9900
# Epoch 16/100
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0426 - accuracy: 0.9900 - val_loss: 0.0283 - val_accuracy: 0.9900
# Epoch 17/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0395 - accuracy: 0.9887 - val_loss: 0.0255 - val_accuracy: 0.9900
# Epoch 18/100
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0370 - accuracy: 0.9887 - val_loss: 0.0231 - val_accuracy: 0.9950
# Epoch 19/100
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0351 - accuracy: 0.9900 - val_loss: 0.0213 - val_accuracy: 0.9950
# Epoch 20/100
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0335 - accuracy: 0.9912 - val_loss: 0.0198 - val_accuracy: 0.9950
# Epoch 21/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0323 - accuracy: 0.9912 - val_loss: 0.0187 - val_accuracy: 0.9950
# Epoch 22/100
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0313 - accuracy: 0.9925 - val_loss: 0.0178 - val_accuracy: 0.9950
# Epoch 23/100
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 24/100
# 1/1 [==============================] - 0s 233ms/step - loss: 0.0300 - accuracy: 0.9912 - val_loss: 0.0165 - val_accuracy: 0.9950
# Epoch 25/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.0161 - val_accuracy: 0.9950
# Epoch 26/100
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.0158 - val_accuracy: 0.9900
# Epoch 27/100
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0156 - val_accuracy: 0.9900
# Epoch 28/100
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.0153 - val_accuracy: 0.9900
# Epoch 29/100
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 0.0152 - val_accuracy: 0.9900
# Epoch 30/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.0150 - val_accuracy: 0.9900
# Epoch 31/100
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0280 - accuracy: 0.9912 - val_loss: 0.0148 - val_accuracy: 0.9900
# Epoch 32/100
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0278 - accuracy: 0.9912 - val_loss: 0.0147 - val_accuracy: 0.9900
# Epoch 33/100
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0275 - accuracy: 0.9925 - val_loss: 0.0145 - val_accuracy: 0.9900
# Epoch 34/100
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0273 - accuracy: 0.9925 - val_loss: 0.0144 - val_accuracy: 0.9900
# Epoch 35/100
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0142 - val_accuracy: 0.9900
# Epoch 36/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0267 - accuracy: 0.9937 - val_loss: 0.0141 - val_accuracy: 0.9900
# Epoch 37/100
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0264 - accuracy: 0.9937 - val_loss: 0.0139 - val_accuracy: 0.9900
# Epoch 38/100
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0262 - accuracy: 0.9937 - val_loss: 0.0138 - val_accuracy: 0.9900
# Epoch 39/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0259 - accuracy: 0.9937 - val_loss: 0.0136 - val_accuracy: 0.9900
# Epoch 40/100
# 1/1 [==============================] - 0s 213ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 0.0135 - val_accuracy: 0.9900
# Epoch 41/100
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0254 - accuracy: 0.9937 - val_loss: 0.0134 - val_accuracy: 0.9900
# Epoch 42/100
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.0133 - val_accuracy: 0.9900
# Epoch 43/100
# 1/1 [==============================] - 0s 220ms/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.0132 - val_accuracy: 0.9950
# Epoch 44/100
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0131 - val_accuracy: 0.9950
# Epoch 45/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 46/100
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 47/100
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 48/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0240 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 49/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 50/100
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 51/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0237 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 52/100
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0236 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 53/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0235 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 54/100
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0234 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 55/100
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 56/100
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 57/100
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 58/100
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 59/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 60/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.0230 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 61/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0229 - accuracy: 0.9950 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 62/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0229 - accuracy: 0.9950 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 63/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0228 - accuracy: 0.9950 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 64/100
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0228 - accuracy: 0.9950 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 65/100
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0227 - accuracy: 0.9950 - val_loss: 0.0126 - val_accuracy: 0.9950
# Epoch 66/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.0126 - val_accuracy: 0.9950
# Epoch 67/100
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.0126 - val_accuracy: 0.9950
# Epoch 68/100
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0225 - accuracy: 0.9950 - val_loss: 0.0126 - val_accuracy: 0.9950
# Epoch 69/100
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0225 - accuracy: 0.9950 - val_loss: 0.0125 - val_accuracy: 0.9950
# Epoch 70/100
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.0125 - val_accuracy: 0.9950
# Epoch 71/100
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.0125 - val_accuracy: 0.9950
# Epoch 72/100
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0124 - val_accuracy: 0.9950
# Epoch 73/100
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0124 - val_accuracy: 0.9950
# Epoch 74/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0124 - val_accuracy: 0.9950
# Epoch 75/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 76/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 77/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 78/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 79/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 80/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 81/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 82/100
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 83/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 84/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 85/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 86/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 87/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 88/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 89/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 90/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 91/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 92/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 93/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 94/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 95/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 96/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# Epoch 97/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# Epoch 98/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# Epoch 99/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# Epoch 100/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9937
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9950
# Trainining accuracy: 0.99
# Testing accuracy: 1.00
# 18.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 3. Gradiente descendente estocástico.
#
# En el gradiente descendente estocástico, una época se considera completa cuando todos los datos de entrenamiento han sido utilizados en la optimización de la red neuronal. En este caso, como en cada iteración se usa una sola muestra, una época se completa en un número de iteraciones igual al tamaño del conjunto de entrenamiento, que en este caso es de 800 iteraciones. Además, dado que el parámetro `epochs` se fija en 100, el entrenamiento de la red se llevará a cabo 80000 iteraciones.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1

model, history = fit_model(batch_size=1)
evaluate(model, history)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0643 - accuracy: 0.9812 - val_loss: 0.1687 - val_accuracy: 0.9550
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0501 - accuracy: 0.9875 - val_loss: 0.0190 - val_accuracy: 0.9900
# Epoch 3/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0914 - accuracy: 0.9825 - val_loss: 0.0177 - val_accuracy: 0.9950
# Epoch 4/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0237 - accuracy: 0.9937 - val_loss: 0.0075 - val_accuracy: 0.9950
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0405 - accuracy: 0.9875 - val_loss: 0.0203 - val_accuracy: 0.9900
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0351 - accuracy: 0.9900 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 7/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9900 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 8/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0312 - accuracy: 0.9900 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 9/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0371 - accuracy: 0.9912 - val_loss: 0.0079 - val_accuracy: 0.9950
# Epoch 10/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0323 - accuracy: 0.9925 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 11/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0474 - accuracy: 0.9887 - val_loss: 0.0131 - val_accuracy: 0.9950
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0398 - accuracy: 0.9850 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 13/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0371 - accuracy: 0.9887 - val_loss: 0.0346 - val_accuracy: 0.9950
# Epoch 14/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0316 - accuracy: 0.9900 - val_loss: 0.0083 - val_accuracy: 0.9950
# Epoch 15/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0272 - accuracy: 0.9900 - val_loss: 0.0081 - val_accuracy: 0.9950
# Epoch 16/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0346 - accuracy: 0.9912 - val_loss: 0.0201 - val_accuracy: 0.9900
# Epoch 17/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 18/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0355 - val_accuracy: 0.9850
# Epoch 19/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0353 - accuracy: 0.9900 - val_loss: 0.0091 - val_accuracy: 0.9950
# Epoch 20/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0246 - accuracy: 0.9950 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0255 - accuracy: 0.9900 - val_loss: 0.0059 - val_accuracy: 0.9950
# Epoch 22/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0252 - accuracy: 0.9887 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 23/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 24/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0272 - accuracy: 0.9900 - val_loss: 0.0078 - val_accuracy: 0.9950
# Epoch 25/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0228 - val_accuracy: 0.9850
# Epoch 26/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0179 - accuracy: 0.9912 - val_loss: 0.0261 - val_accuracy: 0.9900
# Epoch 27/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 28/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0263 - accuracy: 0.9937 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 29/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.0131 - val_accuracy: 0.9950
# Epoch 30/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.0240 - val_accuracy: 0.9850
# Epoch 31/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.0145 - val_accuracy: 0.9900
# Epoch 32/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0260 - accuracy: 0.9937 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 33/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.0109 - val_accuracy: 0.9950
# Epoch 34/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0178 - accuracy: 0.9900 - val_loss: 0.0119 - val_accuracy: 0.9900
# Epoch 35/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0242 - accuracy: 0.9912 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 36/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.0086 - val_accuracy: 0.9950
# Epoch 37/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0274 - accuracy: 0.9900 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 38/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.0439 - val_accuracy: 0.9850
# Epoch 39/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0272 - accuracy: 0.9937 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 40/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 41/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0374 - accuracy: 0.9925 - val_loss: 0.0159 - val_accuracy: 0.9950
# Epoch 43/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 44/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0220 - accuracy: 0.9950 - val_loss: 0.0226 - val_accuracy: 0.9950
# Epoch 45/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0296 - accuracy: 0.9900 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 46/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0176 - accuracy: 0.9962 - val_loss: 0.0331 - val_accuracy: 0.9850
# Epoch 47/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0217 - accuracy: 0.9900 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 48/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0108 - val_accuracy: 0.9950
# Epoch 49/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.0102 - val_accuracy: 0.9950
# Epoch 50/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 51/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 52/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0631 - val_accuracy: 0.9900
# Epoch 53/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0240 - val_accuracy: 0.9900
# Epoch 54/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0189 - accuracy: 0.9925 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 55/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.1068 - accuracy: 0.9812 - val_loss: 0.3196 - val_accuracy: 0.9800
# Epoch 56/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.5716 - accuracy: 0.9812 - val_loss: 0.0292 - val_accuracy: 0.9900
# Epoch 57/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0437 - accuracy: 0.9887 - val_loss: 0.0321 - val_accuracy: 0.9900
# Epoch 58/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.9900 - val_loss: 0.0546 - val_accuracy: 0.9850
# Epoch 59/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0435 - accuracy: 0.9900 - val_loss: 0.0232 - val_accuracy: 0.9950
# Epoch 60/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0368 - accuracy: 0.9912 - val_loss: 0.0220 - val_accuracy: 0.9950
# Epoch 61/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0440 - accuracy: 0.9912 - val_loss: 0.0245 - val_accuracy: 0.9950
# Epoch 62/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0419 - accuracy: 0.9900 - val_loss: 0.0450 - val_accuracy: 0.9900
# Epoch 63/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9850 - val_loss: 0.0260 - val_accuracy: 0.9950
# Epoch 64/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9925 - val_loss: 0.0610 - val_accuracy: 0.9850
# Epoch 65/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0567 - accuracy: 0.9850 - val_loss: 0.0350 - val_accuracy: 0.9900
# Epoch 66/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0306 - accuracy: 0.9937 - val_loss: 0.0478 - val_accuracy: 0.9900
# Epoch 67/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.9937 - val_loss: 0.0638 - val_accuracy: 0.9950
# Epoch 68/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0543 - accuracy: 0.9900 - val_loss: 0.0351 - val_accuracy: 0.9900
# Epoch 69/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0276 - accuracy: 0.9937 - val_loss: 0.0212 - val_accuracy: 0.9950
# Epoch 70/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0317 - accuracy: 0.9925 - val_loss: 0.0159 - val_accuracy: 0.9950
# Epoch 71/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0421 - accuracy: 0.9912 - val_loss: 0.0746 - val_accuracy: 0.9800
# Epoch 72/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0320 - accuracy: 0.9925 - val_loss: 0.0498 - val_accuracy: 0.9900
# Epoch 73/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0384 - accuracy: 0.9900 - val_loss: 0.0646 - val_accuracy: 0.9850
# Epoch 74/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0591 - accuracy: 0.9862 - val_loss: 0.0333 - val_accuracy: 0.9900
# Epoch 75/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0440 - accuracy: 0.9900 - val_loss: 0.0198 - val_accuracy: 0.9950
# Epoch 76/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0331 - accuracy: 0.9875 - val_loss: 0.0257 - val_accuracy: 0.9950
# Epoch 77/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0352 - accuracy: 0.9925 - val_loss: 0.0159 - val_accuracy: 0.9950
# Epoch 78/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0288 - accuracy: 0.9937 - val_loss: 0.0727 - val_accuracy: 0.9800
# Epoch 79/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0304 - accuracy: 0.9912 - val_loss: 0.0153 - val_accuracy: 0.9950
# Epoch 80/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0289 - accuracy: 0.9937 - val_loss: 0.0147 - val_accuracy: 0.9950
# Epoch 81/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0375 - accuracy: 0.9925 - val_loss: 0.0192 - val_accuracy: 0.9950
# Epoch 82/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.0650 - val_accuracy: 0.9850
# Epoch 83/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0440 - accuracy: 0.9875 - val_loss: 0.0473 - val_accuracy: 0.9900
# Epoch 84/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0320 - accuracy: 0.9937 - val_loss: 0.0334 - val_accuracy: 0.9900
# Epoch 85/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0427 - val_accuracy: 0.9900
# Epoch 86/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0339 - accuracy: 0.9912 - val_loss: 0.0686 - val_accuracy: 0.9850
# Epoch 87/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0331 - accuracy: 0.9912 - val_loss: 0.0214 - val_accuracy: 0.9950
# Epoch 88/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0270 - accuracy: 0.9950 - val_loss: 0.0154 - val_accuracy: 0.9950
# Epoch 89/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0336 - accuracy: 0.9950 - val_loss: 0.0488 - val_accuracy: 0.9900
# Epoch 90/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0257 - accuracy: 0.9937 - val_loss: 0.0081 - val_accuracy: 0.9950
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0343 - accuracy: 0.9925 - val_loss: 0.0466 - val_accuracy: 0.9900
# Epoch 92/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0515 - accuracy: 0.9900 - val_loss: 0.0225 - val_accuracy: 0.9950
# Epoch 93/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0276 - accuracy: 0.9937 - val_loss: 0.0140 - val_accuracy: 0.9950
# Epoch 94/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0405 - accuracy: 0.9925 - val_loss: 0.0173 - val_accuracy: 0.9950
# Epoch 95/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0545 - accuracy: 0.9900 - val_loss: 0.0553 - val_accuracy: 0.9850
# Epoch 96/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0399 - accuracy: 0.9900 - val_loss: 0.0491 - val_accuracy: 0.9900
# Epoch 97/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0314 - accuracy: 0.9925 - val_loss: 0.0467 - val_accuracy: 0.9900
# Epoch 98/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0333 - accuracy: 0.9925 - val_loss: 0.0450 - val_accuracy: 0.9900
# Epoch 99/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.0282 - accuracy: 0.9937 - val_loss: 0.0375 - val_accuracy: 0.9900
# Epoch 100/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.0062 - val_accuracy: 1.0000
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9937
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Trainining accuracy: 0.99
# Testing accuracy: 1.00
# 2min 56s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 4. Gradiente descendente por mini-lotes.
#
# Este último enfoque plantea un punto intermedio entre la optimización estocástica y la optimización por lotes. En este algoritmo de optimización por mini-lotes, el conjunto de entrenamiento se divide de forma aleatoria en conjuntos con tamaño `batch_size`. Se debe tener en cuenta que el valor `batch_size` es elegido por el usuario, así que se convierte en un nuevo hiper-parámetro de las redes neuronales.
#
# Siguiendo el análisis de los enfoques anteriores, para el método de gradiente descendente por mini-lotes, una época se completa en $\frac{N}{batch\_size}$ iteraciones, donde $N$ es el tamaño del conjunto de entrenamiento. De esta manera, el entrenamiento se se lleva a cabo en $epochs*\frac{N}{batch\_size}$ iteraciones.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1

model, history = fit_model(batch_size=32)
evaluate(model, history)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 10ms/step - loss: 0.3224 - accuracy: 0.8938 - val_loss: 0.0196 - val_accuracy: 0.9950
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9925 - val_loss: 0.0142 - val_accuracy: 0.9950
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 0.0133 - val_accuracy: 0.9950
# Epoch 4/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 7/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 8/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 9/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0110 - val_accuracy: 0.9950
# Epoch 10/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0108 - val_accuracy: 0.9950
# Epoch 11/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9950 - val_loss: 0.0104 - val_accuracy: 0.9950
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0105 - val_accuracy: 0.9950
# Epoch 13/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0100 - val_accuracy: 0.9950
# Epoch 15/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0104 - val_accuracy: 0.9950
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9950 - val_loss: 0.0099 - val_accuracy: 0.9950
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.0097 - val_accuracy: 0.9950
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 19/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.0097 - val_accuracy: 0.9950
# Epoch 20/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.0095 - val_accuracy: 0.9950
# Epoch 21/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 22/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 0.0092 - val_accuracy: 0.9950
# Epoch 24/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0092 - val_accuracy: 0.9950
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0087 - val_accuracy: 0.9950
# Epoch 27/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.0092 - val_accuracy: 0.9950
# Epoch 28/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0090 - val_accuracy: 0.9950
# Epoch 29/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.0097 - val_accuracy: 0.9950
# Epoch 30/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0089 - val_accuracy: 0.9950
# Epoch 31/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.0091 - val_accuracy: 0.9950
# Epoch 32/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 33/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 34/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 35/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 36/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 38/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0100 - val_accuracy: 0.9950
# Epoch 40/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9937 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9937 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9937 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9950
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Trainining accuracy: 1.00
# Testing accuracy: 1.00
# 11.2 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 4. Conclusiones
#
#
# ### 4.1 Gradiente estocástico por lotes.
# - Este método usa la totalidad de los datos de entrenamiento en cada iteración.
# - Como se nota en los resultados experimentales, la función de pérdida no presenta ruido.
# - La cantidad de iteraciones corresponde al parámetro `epochs`. Esta cantidad es la menor comparada con los otros dos enfoques.
# - Debido a que cada iteración de la optimización usa todos los datos de entrenamiento, este tipo de algoritmos puede presentar problemas en bases de datos con grandes cantidades de muestras o que contienen datos como imágenes o videos. La cantidad de los datos puede desbordar la memoria de nuestros equipos y simplemente no se podría ejecutar el proceso de entrenamiento.
# - Otra desventaja es que dado que la función de pérdida no presenta ruido, este tipo de optimización es propenso a entregar soluciones que no son óptimas, lo cual afecta el rendimiento de las redes neuronales.
#
#
# ### 4.2 Gradiente descendente estocástico.
# - Este método usa una única muestra en cada iteración del entrenamiento, lo cual disminuye al máximo la posibilidad de desbordar la memoria, incluso en bases de datos grandes.
# - La principal desventaja es el ruido presente en la función de pérdida, lo cual causa que la pérdida pueda cambiar abruptamente de una iteración a otra. Este ruido en la función de pérdida causa que el algoritmo sea propenso a no encontrar la solución óptima.
# - Otra desventaja está en el tiempo de ejecución. Este algoritmo debe completar $epochs*N$ iteraciones, lo cual puede incrementar el tiempo de ejecución del algoritmo de optimización.
#
#
# ### 4.3 Gradiente descendente por mini-lotes.
# - Este enfoque es un punto intermedio entre los dos enfoques anteriores, no se usan tantas muestras como el gradiente por lotes ni tan pocas muestras como el gradiente estocástico.
# - Es el enfoque más usado para el entrenamiento de las redes neuronales. El ruido de la función de pérdida es pequeña, lo cual previene cambios abruptos en la pérdida y que se lleguen a soluciones que no son óptimas. Esto se puede notar en los resultados experimentales, donde el gradiente por mini-lotes obtiene el mejor rendimiento con el menor tiempo de ejecución.
# - El gran problema relacionado con este enfoque es que tenemos un nuevo hiper-parámetro por ajustar, el tamaño del mini-lote (`batch_size`). Muchos experimentos en el área del aprendizaje profundo concluyen que la mejor elección es `batch_size` pequeño; de hecho, un buen valor por defecto es `batch_size = 32`.
# - Otro hiper-parámetro que hemos usado es el `momentum`. Este hiper-parámetro está relacionado con una modificación del algoritmo de gradiente descendente, que usa los conceptos estadísticos de la media móvil con el fin de disminuir las oscilaciones de la función de pérdida en los enfoques de gradiente estocástico y gradiente por mini-lotes. Un valor de `momentum` cercano a 1 presenta grandes oscilaciones. Por el contrario, un valor cercano a cero aumenta el suavizado de la función de costo; sin embargo, un valor de `momentum` muy pequeño puede llevar a soluciones que no son óptimas. Para más información se recomienda la siguiente [lectura](https://distill.pub/2017/momentum/) (opcional).
# - El algoritmo de gradiente descendente ha servido como base a nuevos optimizadores más robustos. Dentro de estos, el más usado en la actualidad es el algoritmo ADAM (adaptive moment estimation).
