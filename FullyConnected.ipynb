# %% [markdown]
# <a href="https://colab.research.google.com/github/leonlpz/Reconocimiento_de_Patrones/blob/main/FullyConnected.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programa Ejemplo para Realizar Aprendizaje Supervisado utilizando aprendizaje profundo
#
# ## Etapa 1: Carga de los datos.
#
# Antes de comenzar a definir la red neuronal, cargamos la base de datos de interés. Para este ejemplo, usaremos la base de datos MNIST, la cual consiste en identificar dígitos escritos a mano alzada https://keras.io/api/datasets/mnist/. Esta base de datos configura un problema de 10 clases, una clase por cada dígito numérico (0-9).

# %% [markdown]
# Se cargan las librerías necesarias

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.utils import plot_model

# %% [markdown]
# Se carga la base de datos y se divide en los conjuntos de entrenamiento y prueba. Hay 60000 imágenes para el entrenamiento y 10000 en el conjunto de prueba.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %% [markdown]
# Las imágenes tienen tamaño de 28x28. A continuación, se muestran algunos ejemplos.

# %%
fig = plt.figure()
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i], cmap='gray', interpolation='none')
  plt.title("Digit: {}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %% [markdown]
# Dado que este ejercicio es introductorio solo usaremos la forma más básica de una red neuronal, denominada densa. Esta versión no tiene la capacidad de manipular imágenes en su forma original. Así, aplicaremos una etapa de preprocesamiento a cada imagen con el fin de que las imágenes sean compatibles con las entradas de la red.

# %%
d1, d2, d3 = x_train.shape
x_train_flat = x_train.reshape((d1, d2*d3))/255
d1, d2, d3 = x_test.shape
x_test_flat = x_test.reshape((d1, d2*d3))/255

# %% [markdown]
# La operación llevada a cabo se denomina "aplastamiento" y consiste en convertir un arreglo de dos o más dimensiones en uno de una dimensión. El aplastamiento o flatten consiste en unir las columnas del arreglo (ver https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.w3resource.com%2Fnumpy%2Fmanipulation%2Fndarray-flatten.php&psig=AOvVaw2gj8sBNDTeO-t_T_R15TWv&ust=1675298541750000&source=images&cd=vfe&ved=0CBAQjRxqFwoTCPi0xsWL8_wCFQAAAAAdAAAAABAE)

# %%
print(x_train_flat.shape)
# Out:
# (60000, 784)

# %% [markdown]
# Se mantienen las mismas 60000 imágenes del entrenaminento y se obtienen 784 atributos luego del proceso de aplastamiento. 28*28=784.

# %% [markdown]
# ## Etapa 2: Definición de la red.
#
# Ahora podemos empezar a construir la red neuronal para resolver el problema de clasificación planteado. Keras tienen dos formas para definir una red neuronal. La API secuencial (https://keras.io/guides/sequential_model/) y la API funcional (https://keras.io/guides/functional_api/). En este ejemplo usaremos las API secuencial.

# %% [markdown]
# ### 2.1 Definición de la red usando la API secuencial.
#
# Se define una red con tres capas: dos ocultas y una de salida. Para este ejemplo el tipo de capas usada es la "Dense", en unidades posteriores usaremos otro tipo de capas como las convolucionales y las recurrentes.

# %%
model = Sequential()
# Se define el tamaño de la entrada en 784, que corresponde con la dimensión de los
# datos. La primera capa tiene 1024 unidades con activación ReLU.
model.add(Dense(1024, input_shape=(784,), activation='relu'))
model.add(Dense(512, activation='relu'))
# La tercera capa, corresponde a la capa de salida. Como es un problema de clasificación
# de múltiples clases, la capa de salida debe tener tantas unidades como clases.
# Además, debe usarse la activación softmax.
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Con model.summary() podemos verificar las capas que definimos y la cantidad de
# parámetros en cada capa.
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1024)                │         803,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,333,770 (5.09 MB)
#  Trainable params: 1,333,770 (5.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model)

# %%
# Se compila el modelo. En este punto se define, la función de costo, el optimizador y
# la métrica usada para medir el rendimiento.
# 1. Para el loss se usa el sparse_categorical_crossentropy dado que es un problema de
# clasificación multi-clase.
# 2. Utilizamos el optimizador sgd, el cual es un algoritmo basado en gradiente.
# 3. Finalmente, se usa el accuracy para medir el rendimiento.
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1) #modificar la tasa de aprendizaje
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Ahora, es momento de entrenar la red neuronal, lo cual corresponde a calcular
# parámetros de la red.
# 1. Se pasan los datos de entrenamiento x_train y y_train.
# 2. El número de épocas, en este caso, obedece a la cantidad de repeticiones
#    del entrenamiento.
# 3. El batch_size, será un parámetro que discutiremos en la siguiente unidad,
#    por ahora lo fijamos para que sea igual a la cantidad de muestras en el
#.   conjunto de entrenamiento.
history = model.fit(x_train_flat, y_train, epochs=200, batch_size=60000, validation_data= (x_test_flat, y_test)) #modificar las epocas o entrenamientos
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9315 - loss: 0.2444 - val_accuracy: 0.9341 - val_loss: 0.2368
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step - accuracy: 0.9316 - loss: 0.2441 - val_accuracy: 0.9341 - val_loss: 0.2365
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.9317 - loss: 0.2438 - val_accuracy: 0.9341 - val_loss: 0.2362
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.9318 - loss: 0.2435 - val_accuracy: 0.9341 - val_loss: 0.2360
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 0.9319 - loss: 0.2431 - val_accuracy: 0.9341 - val_loss: 0.2357
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9321 - loss: 0.2428 - val_accuracy: 0.9341 - val_loss: 0.2354
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9321 - loss: 0.2425 - val_accuracy: 0.9341 - val_loss: 0.2351
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9323 - loss: 0.2422 - val_accuracy: 0.9343 - val_loss: 0.2349
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9323 - loss: 0.2419 - val_accuracy: 0.9343 - val_loss: 0.2346
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9324 - loss: 0.2416 - val_accuracy: 0.9344 - val_loss: 0.2343
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9325 - loss: 0.2413 - val_accuracy: 0.9344 - val_loss: 0.2340
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9326 - loss: 0.2410 - val_accuracy: 0.9347 - val_loss: 0.2338
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9326 - loss: 0.2407 - val_accuracy: 0.9350 - val_loss: 0.2335
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9328 - loss: 0.2404 - val_accuracy: 0.9351 - val_loss: 0.2332
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9329 - loss: 0.2401 - val_accuracy: 0.9351 - val_loss: 0.2330
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9329 - loss: 0.2398 - val_accuracy: 0.9352 - val_loss: 0.2327
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9329 - loss: 0.2395 - val_accuracy: 0.9352 - val_loss: 0.2324
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.9331 - loss: 0.2392 - val_accuracy: 0.9352 - val_loss: 0.2322
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9331 - loss: 0.2389 - val_accuracy: 0.9352 - val_loss: 0.2319
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9332 - loss: 0.2386 - val_accuracy: 0.9353 - val_loss: 0.2317
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9333 - loss: 0.2383 - val_accuracy: 0.9355 - val_loss: 0.2314
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9334 - loss: 0.2380 - val_accuracy: 0.9356 - val_loss: 0.2311
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9334 - loss: 0.2377 - val_accuracy: 0.9357 - val_loss: 0.2309
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9335 - loss: 0.2374 - val_accuracy: 0.9358 - val_loss: 0.2306
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step - accuracy: 0.9336 - loss: 0.2371 - val_accuracy: 0.9359 - val_loss: 0.2304
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - accuracy: 0.9337 - loss: 0.2368 - val_accuracy: 0.9360 - val_loss: 0.2301
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - accuracy: 0.9338 - loss: 0.2365 - val_accuracy: 0.9360 - val_loss: 0.2298
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9338 - loss: 0.2362 - val_accuracy: 0.9360 - val_loss: 0.2296
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 0.9339 - loss: 0.2359 - val_accuracy: 0.9360 - val_loss: 0.2293
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9340 - loss: 0.2356 - val_accuracy: 0.9360 - val_loss: 0.2291
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9340 - loss: 0.2354 - val_accuracy: 0.9361 - val_loss: 0.2288
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9340 - loss: 0.2351 - val_accuracy: 0.9364 - val_loss: 0.2286
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9342 - loss: 0.2348 - val_accuracy: 0.9363 - val_loss: 0.2283
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9342 - loss: 0.2345 - val_accuracy: 0.9364 - val_loss: 0.2281
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 0.9344 - loss: 0.2342 - val_accuracy: 0.9365 - val_loss: 0.2278
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 0.9344 - loss: 0.2339 - val_accuracy: 0.9365 - val_loss: 0.2276
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9345 - loss: 0.2337 - val_accuracy: 0.9366 - val_loss: 0.2273
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9346 - loss: 0.2334 - val_accuracy: 0.9367 - val_loss: 0.2271
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - accuracy: 0.9347 - loss: 0.2331 - val_accuracy: 0.9369 - val_loss: 0.2269
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9347 - loss: 0.2328 - val_accuracy: 0.9370 - val_loss: 0.2266
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9348 - loss: 0.2326 - val_accuracy: 0.9370 - val_loss: 0.2264
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9348 - loss: 0.2323 - val_accuracy: 0.9370 - val_loss: 0.2261
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9350 - loss: 0.2320 - val_accuracy: 0.9371 - val_loss: 0.2259
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9351 - loss: 0.2317 - val_accuracy: 0.9371 - val_loss: 0.2256
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9351 - loss: 0.2315 - val_accuracy: 0.9371 - val_loss: 0.2254
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9352 - loss: 0.2312 - val_accuracy: 0.9371 - val_loss: 0.2252
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.9354 - loss: 0.2309 - val_accuracy: 0.9372 - val_loss: 0.2249
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9355 - loss: 0.2306 - val_accuracy: 0.9373 - val_loss: 0.2247
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.9355 - loss: 0.2304 - val_accuracy: 0.9373 - val_loss: 0.2244
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9356 - loss: 0.2301 - val_accuracy: 0.9373 - val_loss: 0.2242
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9356 - loss: 0.2298 - val_accuracy: 0.9375 - val_loss: 0.2240
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9357 - loss: 0.2296 - val_accuracy: 0.9375 - val_loss: 0.2237
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9358 - loss: 0.2293 - val_accuracy: 0.9379 - val_loss: 0.2235
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 0.9359 - loss: 0.2290 - val_accuracy: 0.9379 - val_loss: 0.2233
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9359 - loss: 0.2288 - val_accuracy: 0.9379 - val_loss: 0.2230
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9360 - loss: 0.2285 - val_accuracy: 0.9379 - val_loss: 0.2228
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - accuracy: 0.9361 - loss: 0.2282 - val_accuracy: 0.9380 - val_loss: 0.2226
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.9361 - loss: 0.2280 - val_accuracy: 0.9382 - val_loss: 0.2223
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9362 - loss: 0.2277 - val_accuracy: 0.9383 - val_loss: 0.2221
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9362 - loss: 0.2274 - val_accuracy: 0.9383 - val_loss: 0.2219
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.9363 - loss: 0.2272 - val_accuracy: 0.9383 - val_loss: 0.2216
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9365 - loss: 0.2269 - val_accuracy: 0.9383 - val_loss: 0.2214
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9365 - loss: 0.2267 - val_accuracy: 0.9384 - val_loss: 0.2212
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9366 - loss: 0.2264 - val_accuracy: 0.9384 - val_loss: 0.2210
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.9366 - loss: 0.2262 - val_accuracy: 0.9384 - val_loss: 0.2207
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9366 - loss: 0.2259 - val_accuracy: 0.9382 - val_loss: 0.2205
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.9367 - loss: 0.2256 - val_accuracy: 0.9383 - val_loss: 0.2203
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9367 - loss: 0.2254 - val_accuracy: 0.9383 - val_loss: 0.2201
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9368 - loss: 0.2251 - val_accuracy: 0.9383 - val_loss: 0.2198
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step - accuracy: 0.9369 - loss: 0.2249 - val_accuracy: 0.9383 - val_loss: 0.2196
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9370 - loss: 0.2246 - val_accuracy: 0.9385 - val_loss: 0.2194
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - accuracy: 0.9370 - loss: 0.2244 - val_accuracy: 0.9385 - val_loss: 0.2192
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9371 - loss: 0.2241 - val_accuracy: 0.9387 - val_loss: 0.2189
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - accuracy: 0.9372 - loss: 0.2239 - val_accuracy: 0.9388 - val_loss: 0.2187
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 0.9373 - loss: 0.2236 - val_accuracy: 0.9388 - val_loss: 0.2185
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9374 - loss: 0.2234 - val_accuracy: 0.9389 - val_loss: 0.2183
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 0.9374 - loss: 0.2231 - val_accuracy: 0.9389 - val_loss: 0.2181
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9376 - loss: 0.2229 - val_accuracy: 0.9390 - val_loss: 0.2178
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9377 - loss: 0.2226 - val_accuracy: 0.9389 - val_loss: 0.2176
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - accuracy: 0.9377 - loss: 0.2224 - val_accuracy: 0.9389 - val_loss: 0.2174
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step - accuracy: 0.9377 - loss: 0.2221 - val_accuracy: 0.9391 - val_loss: 0.2172
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.9379 - loss: 0.2219 - val_accuracy: 0.9391 - val_loss: 0.2170
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.9379 - loss: 0.2216 - val_accuracy: 0.9391 - val_loss: 0.2168
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9380 - loss: 0.2214 - val_accuracy: 0.9390 - val_loss: 0.2165
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 0.9381 - loss: 0.2212 - val_accuracy: 0.9390 - val_loss: 0.2163
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9381 - loss: 0.2209 - val_accuracy: 0.9391 - val_loss: 0.2161
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9382 - loss: 0.2207 - val_accuracy: 0.9391 - val_loss: 0.2159
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9383 - loss: 0.2204 - val_accuracy: 0.9394 - val_loss: 0.2157
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 0.9384 - loss: 0.2202 - val_accuracy: 0.9396 - val_loss: 0.2155
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9384 - loss: 0.2199 - val_accuracy: 0.9396 - val_loss: 0.2153
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9384 - loss: 0.2197 - val_accuracy: 0.9398 - val_loss: 0.2150
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9386 - loss: 0.2195 - val_accuracy: 0.9398 - val_loss: 0.2148
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9386 - loss: 0.2192 - val_accuracy: 0.9398 - val_loss: 0.2146
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9387 - loss: 0.2190 - val_accuracy: 0.9399 - val_loss: 0.2144
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9388 - loss: 0.2187 - val_accuracy: 0.9399 - val_loss: 0.2142
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9388 - loss: 0.2185 - val_accuracy: 0.9399 - val_loss: 0.2140
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 0.9390 - loss: 0.2183 - val_accuracy: 0.9400 - val_loss: 0.2138
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.9390 - loss: 0.2180 - val_accuracy: 0.9401 - val_loss: 0.2136
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9391 - loss: 0.2178 - val_accuracy: 0.9401 - val_loss: 0.2134
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9392 - loss: 0.2176 - val_accuracy: 0.9401 - val_loss: 0.2132
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9392 - loss: 0.2173 - val_accuracy: 0.9402 - val_loss: 0.2130
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9393 - loss: 0.2171 - val_accuracy: 0.9403 - val_loss: 0.2128
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.9394 - loss: 0.2169 - val_accuracy: 0.9403 - val_loss: 0.2125
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step - accuracy: 0.9395 - loss: 0.2166 - val_accuracy: 0.9403 - val_loss: 0.2123
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9395 - loss: 0.2164 - val_accuracy: 0.9404 - val_loss: 0.2121
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9395 - loss: 0.2162 - val_accuracy: 0.9405 - val_loss: 0.2119
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.9396 - loss: 0.2159 - val_accuracy: 0.9406 - val_loss: 0.2117
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9396 - loss: 0.2157 - val_accuracy: 0.9406 - val_loss: 0.2115
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step - accuracy: 0.9397 - loss: 0.2155 - val_accuracy: 0.9408 - val_loss: 0.2113
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9397 - loss: 0.2153 - val_accuracy: 0.9409 - val_loss: 0.2111
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9398 - loss: 0.2150 - val_accuracy: 0.9409 - val_loss: 0.2109
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9399 - loss: 0.2148 - val_accuracy: 0.9408 - val_loss: 0.2107
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9400 - loss: 0.2146 - val_accuracy: 0.9408 - val_loss: 0.2105
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9400 - loss: 0.2143 - val_accuracy: 0.9408 - val_loss: 0.2103
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - accuracy: 0.9401 - loss: 0.2141 - val_accuracy: 0.9410 - val_loss: 0.2101
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9401 - loss: 0.2139 - val_accuracy: 0.9410 - val_loss: 0.2099
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 0.9402 - loss: 0.2137 - val_accuracy: 0.9412 - val_loss: 0.2097
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9403 - loss: 0.2134 - val_accuracy: 0.9413 - val_loss: 0.2095
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9403 - loss: 0.2132 - val_accuracy: 0.9415 - val_loss: 0.2093
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9404 - loss: 0.2130 - val_accuracy: 0.9416 - val_loss: 0.2091
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9405 - loss: 0.2128 - val_accuracy: 0.9417 - val_loss: 0.2089
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9406 - loss: 0.2126 - val_accuracy: 0.9417 - val_loss: 0.2087
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9406 - loss: 0.2123 - val_accuracy: 0.9417 - val_loss: 0.2085
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9407 - loss: 0.2121 - val_accuracy: 0.9418 - val_loss: 0.2083
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.9408 - loss: 0.2119 - val_accuracy: 0.9418 - val_loss: 0.2082
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9409 - loss: 0.2117 - val_accuracy: 0.9418 - val_loss: 0.2080
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9409 - loss: 0.2114 - val_accuracy: 0.9421 - val_loss: 0.2078
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9410 - loss: 0.2112 - val_accuracy: 0.9422 - val_loss: 0.2076
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9411 - loss: 0.2110 - val_accuracy: 0.9423 - val_loss: 0.2074
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9411 - loss: 0.2108 - val_accuracy: 0.9423 - val_loss: 0.2072
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9412 - loss: 0.2106 - val_accuracy: 0.9425 - val_loss: 0.2070
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9412 - loss: 0.2104 - val_accuracy: 0.9426 - val_loss: 0.2068
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step - accuracy: 0.9413 - loss: 0.2101 - val_accuracy: 0.9427 - val_loss: 0.2066
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9414 - loss: 0.2099 - val_accuracy: 0.9427 - val_loss: 0.2064
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9414 - loss: 0.2097 - val_accuracy: 0.9428 - val_loss: 0.2062
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9415 - loss: 0.2095 - val_accuracy: 0.9428 - val_loss: 0.2060
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9416 - loss: 0.2093 - val_accuracy: 0.9428 - val_loss: 0.2059
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.9417 - loss: 0.2091 - val_accuracy: 0.9428 - val_loss: 0.2057
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9417 - loss: 0.2088 - val_accuracy: 0.9429 - val_loss: 0.2055
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.9418 - loss: 0.2086 - val_accuracy: 0.9430 - val_loss: 0.2053
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9419 - loss: 0.2084 - val_accuracy: 0.9430 - val_loss: 0.2051
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9419 - loss: 0.2082 - val_accuracy: 0.9430 - val_loss: 0.2049
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 0.9419 - loss: 0.2080 - val_accuracy: 0.9431 - val_loss: 0.2047
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9419 - loss: 0.2078 - val_accuracy: 0.9433 - val_loss: 0.2045
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9420 - loss: 0.2076 - val_accuracy: 0.9433 - val_loss: 0.2044
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9421 - loss: 0.2074 - val_accuracy: 0.9433 - val_loss: 0.2042
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9421 - loss: 0.2072 - val_accuracy: 0.9434 - val_loss: 0.2040
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9422 - loss: 0.2069 - val_accuracy: 0.9433 - val_loss: 0.2038
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.9423 - loss: 0.2067 - val_accuracy: 0.9434 - val_loss: 0.2036
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9423 - loss: 0.2065 - val_accuracy: 0.9434 - val_loss: 0.2034
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9423 - loss: 0.2063 - val_accuracy: 0.9434 - val_loss: 0.2032
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9424 - loss: 0.2061 - val_accuracy: 0.9434 - val_loss: 0.2031
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9424 - loss: 0.2059 - val_accuracy: 0.9435 - val_loss: 0.2029
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 0.9426 - loss: 0.2057 - val_accuracy: 0.9437 - val_loss: 0.2027
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9426 - loss: 0.2055 - val_accuracy: 0.9438 - val_loss: 0.2025
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - accuracy: 0.9426 - loss: 0.2053 - val_accuracy: 0.9438 - val_loss: 0.2023
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.9426 - loss: 0.2051 - val_accuracy: 0.9438 - val_loss: 0.2022
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - accuracy: 0.9427 - loss: 0.2049 - val_accuracy: 0.9438 - val_loss: 0.2020
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.9428 - loss: 0.2047 - val_accuracy: 0.9438 - val_loss: 0.2018
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - accuracy: 0.9429 - loss: 0.2045 - val_accuracy: 0.9439 - val_loss: 0.2016
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - accuracy: 0.9430 - loss: 0.2043 - val_accuracy: 0.9441 - val_loss: 0.2014
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9431 - loss: 0.2041 - val_accuracy: 0.9442 - val_loss: 0.2013
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.9431 - loss: 0.2039 - val_accuracy: 0.9442 - val_loss: 0.2011
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9432 - loss: 0.2036 - val_accuracy: 0.9443 - val_loss: 0.2009
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9433 - loss: 0.2034 - val_accuracy: 0.9444 - val_loss: 0.2007
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9433 - loss: 0.2032 - val_accuracy: 0.9445 - val_loss: 0.2005
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9433 - loss: 0.2030 - val_accuracy: 0.9446 - val_loss: 0.2004
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9433 - loss: 0.2028 - val_accuracy: 0.9446 - val_loss: 0.2002
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9433 - loss: 0.2026 - val_accuracy: 0.9448 - val_loss: 0.2000
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 0.9434 - loss: 0.2024 - val_accuracy: 0.9448 - val_loss: 0.1998
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9434 - loss: 0.2022 - val_accuracy: 0.9448 - val_loss: 0.1997
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9435 - loss: 0.2020 - val_accuracy: 0.9448 - val_loss: 0.1995
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9436 - loss: 0.2018 - val_accuracy: 0.9448 - val_loss: 0.1993
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.9436 - loss: 0.2016 - val_accuracy: 0.9448 - val_loss: 0.1991
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9437 - loss: 0.2014 - val_accuracy: 0.9448 - val_loss: 0.1989
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 0.9437 - loss: 0.2012 - val_accuracy: 0.9449 - val_loss: 0.1988
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9437 - loss: 0.2010 - val_accuracy: 0.9449 - val_loss: 0.1986
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9438 - loss: 0.2009 - val_accuracy: 0.9448 - val_loss: 0.1984
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9439 - loss: 0.2007 - val_accuracy: 0.9449 - val_loss: 0.1983
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9440 - loss: 0.2005 - val_accuracy: 0.9449 - val_loss: 0.1981
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9441 - loss: 0.2003 - val_accuracy: 0.9449 - val_loss: 0.1979
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.9441 - loss: 0.2001 - val_accuracy: 0.9451 - val_loss: 0.1977
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9442 - loss: 0.1999 - val_accuracy: 0.9451 - val_loss: 0.1976
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9443 - loss: 0.1997 - val_accuracy: 0.9451 - val_loss: 0.1974
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9444 - loss: 0.1995 - val_accuracy: 0.9451 - val_loss: 0.1972
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 0.9444 - loss: 0.1993 - val_accuracy: 0.9451 - val_loss: 0.1970
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9444 - loss: 0.1991 - val_accuracy: 0.9452 - val_loss: 0.1969
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - accuracy: 0.9445 - loss: 0.1989 - val_accuracy: 0.9452 - val_loss: 0.1967
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - accuracy: 0.9445 - loss: 0.1987 - val_accuracy: 0.9452 - val_loss: 0.1965
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9446 - loss: 0.1985 - val_accuracy: 0.9452 - val_loss: 0.1964
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9446 - loss: 0.1983 - val_accuracy: 0.9453 - val_loss: 0.1962
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9446 - loss: 0.1981 - val_accuracy: 0.9453 - val_loss: 0.1960
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step - accuracy: 0.9447 - loss: 0.1979 - val_accuracy: 0.9453 - val_loss: 0.1959
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.9448 - loss: 0.1978 - val_accuracy: 0.9453 - val_loss: 0.1957
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9448 - loss: 0.1976 - val_accuracy: 0.9453 - val_loss: 0.1955
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9449 - loss: 0.1974 - val_accuracy: 0.9453 - val_loss: 0.1954
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9449 - loss: 0.1972 - val_accuracy: 0.9453 - val_loss: 0.1952
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9450 - loss: 0.1970 - val_accuracy: 0.9454 - val_loss: 0.1950
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9451 - loss: 0.1968 - val_accuracy: 0.9455 - val_loss: 0.1949
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9451 - loss: 0.1966 - val_accuracy: 0.9457 - val_loss: 0.1947

# %%
test_loss, test_acc = model.evaluate(x_test_flat, y_test)
print('test_acc:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9363 - loss: 0.2272
# test_acc: 0.9456999897956848

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.show()
